# %%
import numpy as np
import pandas as pd

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
df = pd.read_csv(
    'energy.csv')

# %%
df.head(5)
# Out:
#      X1     X2     X3      X4   X5  X6   X7  X8     Y1     Y2
# 0  0.98  514.5  294.0  110.25  7.0   2  0.0   0  15.55  21.33
# 1  0.98  514.5  294.0  110.25  7.0   3  0.0   0  15.55  21.33
# 2  0.98  514.5  294.0  110.25  7.0   4  0.0   0  15.55  21.33
# 3  0.98  514.5  294.0  110.25  7.0   5  0.0   0  15.55  21.33
# 4  0.90  563.5  318.5  122.50  7.0   2  0.0   0  20.84  28.28

# %%
df.plot(figsize=(16, 9))
# Out:
# <AxesSubplot:>

# %%
pd.notnull(None)
# Out:
# False

# %%
df.shape
# Out:
# (768, 10)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   X1      768 non-null    float64
#  1   X2      768 non-null    float64
#  2   X3      768 non-null    float64
#  3   X4      768 non-null    float64
#  4   X5      768 non-null    float64
#  5   X6      768 non-null    int64
#  6   X7      768 non-null    float64
#  7   X8      768 non-null    int64
#  8   Y1      768 non-null    float64
#  9   Y2      768 non-null    float64
# dtypes: float64(8), int64(2)
# memory usage: 60.1 KB

# %%
df.isnull()
# Out:
#         X1     X2     X3     X4     X5     X6     X7     X8     Y1     Y2
# 0    False  False  False  False  False  False  False  False  False  False
# 1    False  False  False  False  False  False  False  False  False  False
# 2    False  False  False  False  False  False  False  False  False  False
# 3    False  False  False  False  False  False  False  False  False  False
# 4    False  False  False  False  False  False  False  False  False  False
# ..     ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 763  False  False  False  False  False  False  False  False  False  False
# 764  False  False  False  False  False  False  False  False  False  False
# 765  False  False  False  False  False  False  False  False  False  False
# 766  False  False  False  False  False  False  False  False  False  False
# 767  False  False  False  False  False  False  False  False  False  False
#
# [768 rows x 10 columns]

# %%
df.isnull().sum()
# Out:
# X1    0
# X2    0
# X3    0
# X4    0
# X5    0
# X6    0
# X7    0
# X8    0
# Y1    0
# Y2    0
# dtype: int64

# %%
df.columns = ['Relative Compactness','Surface Area','Wall Area','Roof Area','Overall Height' ,'Orientation' ,'Glazing Area'
              ,'Glazing Area Distribution','Heating Load','Cooling Load']

# %%
df.head(5)
# Out:
#    Relative Compactness  Surface Area  Wall Area  Roof Area  Overall Height  \
# 0                  0.98         514.5      294.0     110.25             7.0
# 1                  0.98         514.5      294.0     110.25             7.0
# 2                  0.98         514.5      294.0     110.25             7.0
# 3                  0.98         514.5      294.0     110.25             7.0
# 4                  0.90         563.5      318.5     122.50             7.0
#
#    Orientation  Glazing Area  Glazing Area Distribution  Heating Load  \
# 0            2           0.0                          0         15.55
# 1            3           0.0                          0         15.55
# 2            4           0.0                          0         15.55
# 3            5           0.0                          0         15.55
# 4            2           0.0                          0         20.84
#
#    Cooling Load
# 0         21.33
# 1         21.33
# 2         21.33
# 3         21.33
# 4         28.28

# %%
plt.boxplot(df, notch=None, vert=None, patch_artist=None, widths=None)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x17a1218c550>,
#   <matplotlib.lines.Line2D at 0x17a1218c8e0>,
#   <matplotlib.lines.Line2D at 0x17a12199eb0>,
#   <matplotlib.lines.Line2D at 0x17a121a5280>,
#   <matplotlib.lines.Line2D at 0x17a121b2820>,
#   <matplotlib.lines.Line2D at 0x17a121b2bb0>,
#   <matplotlib.lines.Line2D at 0x17a121c9190>,
#   <matplotlib.lines.Line2D at 0x17a121c9520>,
#   <matplotlib.lines.Line2D at 0x17a121d3ac0>,
#   <matplotlib.lines.Line2D at 0x17a121d3e50>,
#   <matplotlib.lines.Line2D at 0x17a121eb430>,
#   <matplotlib.lines.Line2D at 0x17a121eb7c0>,
#   <matplotlib.lines.Line2D at 0x17a121f7d60>,
#   <matplotlib.lines.Line2D at 0x17a12204130>,
#   <matplotlib.lines.Line2D at 0x17a1220e6d0>,
#   <matplotlib.lines.Line2D at 0x17a1220ea60>,
#   <matplotlib.lines.Line2D at 0x17a12228040>,
#   <matplotlib.lines.Line2D at 0x17a122283d0>,
#   <matplotlib.lines.Line2D at 0x17a12231970>,
#   <matplotlib.lines.Line2D at 0x17a12231d00>],
#  'caps': [<matplotlib.lines.Line2D at 0x17a1218cc70>,
#   <matplotlib.lines.Line2D at 0x17a12199040>,
#   <matplotlib.lines.Line2D at 0x17a121a5610>,
#   <matplotlib.lines.Line2D at 0x17a121a59a0>,
#   <matplotlib.lines.Line2D at 0x17a121b2f40>,
#   <matplotlib.lines.Line2D at 0x17a121bd310>,
#   <matplotlib.lines.Line2D at 0x17a121c98b0>,
#   <matplotlib.lines.Line2D at 0x17a121c9c40>,
#   <matplotlib.lines.Line2D at 0x17a121e0220>,
#   <matplotlib.lines.Line2D at 0x17a121e05b0>,
#   <matplotlib.lines.Line2D at 0x17a121ebb50>,
#   <matplotlib.lines.Line2D at 0x17a121ebee0>,
#   <matplotlib.lines.Line2D at 0x17a122044c0>,
#   <matplotlib.lines.Line2D at 0x17a12204850>,
#   <matplotlib.lines.Line2D at 0x17a1220edf0>,
#   <matplotlib.lines.Line2D at 0x17a1221a1c0>,
#   <matplotlib.lines.Line2D at 0x17a12228760>,
#   <matplotlib.lines.Line2D at 0x17a12228af0>,
#   <matplotlib.lines.Line2D at 0x17a1223e0d0>,
#   <matplotlib.lines.Line2D at 0x17a1223e460>],
#  'boxes': [<matplotlib.lines.Line2D at 0x17a1218c1c0>,
#   <matplotlib.lines.Line2D at 0x17a12199b20>,
#   <matplotlib.lines.Line2D at 0x17a121b2490>,
#   <matplotlib.lines.Line2D at 0x17a121bddc0>,
#   <matplotlib.lines.Line2D at 0x17a121d3730>,
#   <matplotlib.lines.Line2D at 0x17a121eb0a0>,
#   <matplotlib.lines.Line2D at 0x17a121f79d0>,
#   <matplotlib.lines.Line2D at 0x17a1220e340>,
#   <matplotlib.lines.Line2D at 0x17a1221ac70>,
#   <matplotlib.lines.Line2D at 0x17a122315e0>],
#  'medians': [<matplotlib.lines.Line2D at 0x17a121993d0>,
#   <matplotlib.lines.Line2D at 0x17a121a5d30>,
#   <matplotlib.lines.Line2D at 0x17a121bd6a0>,
#   <matplotlib.lines.Line2D at 0x17a121c9fd0>,
#   <matplotlib.lines.Line2D at 0x17a121e0940>,
#   <matplotlib.lines.Line2D at 0x17a121f72b0>,
#   <matplotlib.lines.Line2D at 0x17a12204be0>,
#   <matplotlib.lines.Line2D at 0x17a1221a550>,
#   <matplotlib.lines.Line2D at 0x17a12228e80>,
#   <matplotlib.lines.Line2D at 0x17a1223e7f0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x17a12199760>,
#   <matplotlib.lines.Line2D at 0x17a121b2100>,
#   <matplotlib.lines.Line2D at 0x17a121bda30>,
#   <matplotlib.lines.Line2D at 0x17a121d33a0>,
#   <matplotlib.lines.Line2D at 0x17a121e0cd0>,
#   <matplotlib.lines.Line2D at 0x17a121f7640>,
#   <matplotlib.lines.Line2D at 0x17a12204f70>,
#   <matplotlib.lines.Line2D at 0x17a1221a8e0>,
#   <matplotlib.lines.Line2D at 0x17a12231250>,
#   <matplotlib.lines.Line2D at 0x17a1223eb80>],
#  'means': []}

# %%
df.mean()
# Out:
# Relative Compactness           0.764167
# Surface Area                 671.708333
# Wall Area                    318.500000
# Roof Area                    176.604167
# Overall Height                 5.250000
# Orientation                    3.500000
# Glazing Area                   0.234375
# Glazing Area Distribution      2.812500
# Heating Load                  22.307201
# Cooling Load                  24.587760
# dtype: float64

# %%
df.median()
# Out:
# Relative Compactness           0.75
# Surface Area                 673.75
# Wall Area                    318.50
# Roof Area                    183.75
# Overall Height                 5.25
# Orientation                    3.50
# Glazing Area                   0.25
# Glazing Area Distribution      3.00
# Heating Load                  18.95
# Cooling Load                  22.08
# dtype: float64

# %%
df['Heating Load'].max() - df['Heating Load'].min()
# Out:
# 37.09

# %%
df['Cooling Load'].max() - df['Cooling Load'].min()
# Out:
# 37.13

# %%
df[['Heating Load','Cooling Load']].var()
# Out:
# Heating Load    101.812050
# Cooling Load     90.502983
# dtype: float64

# %%
df[['Heating Load', 'Cooling Load']].std()
# Out:
# Heating Load    10.090196
# Cooling Load     9.513306
# dtype: float64

# %%
df.std()
# Out:
# Relative Compactness          0.105777
# Surface Area                 88.086116
# Wall Area                    43.626481
# Roof Area                    45.165950
# Overall Height                1.751140
# Orientation                   1.118763
# Glazing Area                  0.133221
# Glazing Area Distribution     1.550960
# Heating Load                 10.090196
# Cooling Load                  9.513306
# dtype: float64

# %%
import seaborn as sns

# %%
df["Heating Load"].plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df["Cooling Load"].plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
plt.scatter(df['Surface Area'], df['Heating Load'])
df.plot(x='Surface Area', y='Heating Load')
# Out:
# <AxesSubplot:xlabel='Surface Area'>

# %%
plt.scatter(df['Roof Area'], df['Heating Load'])

# %%
plt.scatter(df['Relative Compactness'], df['Heating Load'])

# %%
plt.scatter(df['Surface Area'], df['Cooling Load'])
df.plot(x='Surface Area', y='Cooling Load')
# Out:
# <AxesSubplot:xlabel='Surface Area'>

# %%
plt.scatter(df['Roof Area'], df['Cooling Load'])

# %%
plt.scatter(df['Relative Compactness'], df['Cooling Load'])

# %%
train, validate, test = \
              np.split(df.sample(frac=1, random_state=42), 
                       [int(.6*len(df)), int(.8*len(df))])

# %%
train
# Out:
#      Relative Compactness  Surface Area  Wall Area  Roof Area  Overall Height  \
# 668                  0.62         808.5      367.5     220.50             3.5
# 324                  0.66         759.5      318.5     220.50             3.5
# 624                  0.98         514.5      294.0     110.25             7.0
# 690                  0.79         637.0      343.0     147.00             7.0
# 473                  0.64         784.0      343.0     220.50             3.5
# ..                    ...           ...        ...        ...             ...
# 190                  0.62         808.5      367.5     220.50             3.5
# 115                  0.79         637.0      343.0     147.00             7.0
# 732                  0.82         612.5      318.5     147.00             7.0
# 467                  0.69         735.0      294.0     220.50             3.5
# 94                   0.62         808.5      367.5     220.50             3.5
#
#      Orientation  Glazing Area  Glazing Area Distribution  Heating Load  \
# 668            2          0.40                          3         16.47
# 324            2          0.25                          1         13.17
# 624            2          0.40                          3         32.82
# 690            4          0.40                          4         41.32
# 473            3          0.25                          4         16.69
# ..           ...           ...                        ...           ...
# 190            4          0.10                          3         12.71
# 115            5          0.10                          2         36.03
# 732            2          0.40                          5         30.00
# 467            5          0.25                          4         12.86
# 94             4          0.10                          1         12.93
#
#      Cooling Load
# 668         16.90
# 324         16.39
# 624         32.78
# 690         46.23
# 473         19.76
# ..            ...
# 190         14.14
# 115         42.86
# 732         29.93
# 467         16.13
# 94          14.33
#
# [460 rows x 10 columns]

# %%
validate
# Out:
#      Relative Compactness  Surface Area  Wall Area  Roof Area  Overall Height  \
# 180                  0.66         759.5      318.5     220.50             3.5
# 301                  0.82         612.5      318.5     147.00             7.0
# 736                  0.79         637.0      343.0     147.00             7.0
# 569                  0.64         784.0      343.0     220.50             3.5
# 628                  0.90         563.5      318.5     122.50             7.0
# ..                    ...           ...        ...        ...             ...
# 384                  0.98         514.5      294.0     110.25             7.0
# 224                  0.69         735.0      294.0     220.50             3.5
# 729                  0.86         588.0      294.0     147.00             7.0
# 630                  0.90         563.5      318.5     122.50             7.0
# 472                  0.64         784.0      343.0     220.50             3.5
#
#      Orientation  Glazing Area  Glazing Area Distribution  Heating Load  \
# 180            2          0.10                          3         11.59
# 301            3          0.25                          1         27.27
# 736            2          0.40                          5         42.11
# 569            3          0.40                          1         19.36
# 628            2          0.40                          3         34.24
# ..           ...           ...                        ...           ...
# 384            2          0.25                          3         28.67
# 224            2          0.10                          4         11.18
# 729            3          0.40                          5         31.81
# 630            4          0.40                          3         35.05
# 472            2          0.25                          4         16.99
#
#      Cooling Load
# 180         13.46
# 301         27.84
# 736         38.56
# 569         22.73
# 628         37.26
# ..            ...
# 384         29.43
# 224         14.29
# 729         31.20
# 630         33.82
# 472         19.65
#
# [154 rows x 10 columns]

# %%
test
# Out:
#      Relative Compactness  Surface Area  Wall Area  Roof Area  Overall Height  \
# 347                  0.86         588.0      294.0     147.00             7.0
# 505                  0.74         686.0      245.0     220.50             3.5
# 756                  0.66         759.5      318.5     220.50             3.5
# 710                  0.66         759.5      318.5     220.50             3.5
# 693                  0.76         661.5      416.5     122.50             7.0
# ..                    ...           ...        ...        ...             ...
# 71                   0.76         661.5      416.5     122.50             7.0
# 106                  0.86         588.0      294.0     147.00             7.0
# 270                  0.71         710.5      269.5     220.50             3.5
# 435                  0.98         514.5      294.0     110.25             7.0
# 102                  0.90         563.5      318.5     122.50             7.0
#
#      Orientation  Glazing Area  Glazing Area Distribution  Heating Load  \
# 347            5          0.25                          2         28.40
# 505            3          0.25                          5         11.67
# 756            2          0.40                          5         14.96
# 710            4          0.40                          4         15.09
# 693            3          0.40                          4         40.40
# ..           ...           ...                        ...           ...
# 71             5          0.10                          1         32.21
# 106            4          0.10                          2         26.33
# 270            4          0.10                          5         10.67
# 435            5          0.25                          4         28.62
# 102            4          0.10                          2         28.83
#
#      Cooling Load
# 347         34.52
# 505         14.58
# 756         17.64
# 710         18.36
# 693         39.67
# ..            ...
# 71          33.67
# 106         27.36
# 270         14.26
# 435         30.12
# 102         29.36
#
# [154 rows x 10 columns]

# %%
train.mean()
# Out:
# Relative Compactness           0.761283
# Surface Area                 674.389130
# Wall Area                    320.523913
# Roof Area                    176.932609
# Overall Height                 5.242391
# Orientation                    3.515217
# Glazing Area                   0.231848
# Glazing Area Distribution      2.769565
# Heating Load                  22.460478
# Cooling Load                  24.670522
# dtype: float64

# %%
test.mean()
# Out:
# Relative Compactness           0.762662
# Surface Area                 673.113636
# Wall Area                    314.363636
# Roof Area                    179.375000
# Overall Height                 5.113636
# Orientation                    3.487013
# Glazing Area                   0.228571
# Glazing Area Distribution      2.779221
# Heating Load                  20.916104
# Cooling Load                  23.473117
# dtype: float64

# %%
from sklearn.datasets import make_regression
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import KFold, train_test_split,GridSearchCV, cross_val_predict, cross_val_score
from sklearn.metrics import mean_squared_error, r2_score
from numpy import mean
from numpy import absolute
from numpy import sqrt
from sklearn.neighbors import KNeighborsRegressor
from sklearn import metrics

# %%
cv = KFold(n_splits=10, random_state=1, shuffle=True)

# %%
model = LinearRegression()

# %%
X_train = train.drop(['Heating Load'],axis = 1)
y_train = train['Heating Load']

# %%
X_test = test.drop(['Heating Load'],axis = 1)
y_test = test['Heating Load']

# %%
A_train = train.drop(['Cooling Load'],axis = 1)
b_train = train['Cooling Load']

# %%
A_test = test.drop(['Cooling Load'],axis = 1)
b_test = test['Cooling Load']

# %%
X_train.shape
# Out:
# (460, 9)

# %%
X_test.shape
# Out:
# (154, 9)

# %%
y_train.shape
# Out:
# (460,)

# %%
y_test.shape
# Out:
# (154,)

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rf = RandomForestRegressor()

# %%
rf.fit(X_train, y_train)
# Out:
# RandomForestRegressor()

# %%
rf.fit(A_train, b_train)
# Out:
# RandomForestRegressor()

# %%
z_pred = rf.predict(A_test)

# %%
z_pred
# Out:
# array([31.8555, 14.5664, 17.267 , 17.6649, 39.8686, 16.7387, 16.586 ,
#        16.8087, 33.333 , 13.8776, 26.7848, 27.0843, 14.7853, 11.9935,
#        32.0999, 13.4983, 17.8926, 16.3468, 33.7554, 14.4674, 17.1224,
#        26.7321, 17.1721, 14.9224, 17.0898, 36.9971, 26.4902, 32.2884,
#        27.0821, 16.2804, 13.3307, 24.7497, 38.9809, 29.8647, 17.9387,
#        38.9792, 25.7257, 17.2967, 39.0136, 36.9582, 12.2007, 11.9656,
#        28.5338, 14.7542, 11.237 , 38.8175, 14.7923, 31.054 , 20.6456,
#        30.4403, 15.0934, 33.5047, 46.6758, 44.3491, 19.3252, 26.4673,
#        16.0409, 39.3028, 14.6039, 16.9898, 19.8885, 39.3999, 23.2914,
#        27.2708, 16.5567, 27.1093, 20.6627, 19.3087, 13.3387, 32.4578,
#        29.7238, 34.1025, 28.1894, 15.0536, 37.1773, 16.9627, 14.0104,
#        28.9713, 40.8744, 17.153 , 44.0518, 15.1466, 26.7564, 17.9704,
#        33.6953, 21.5214, 17.006 , 17.2037, 14.5117, 26.9216, 12.0538,
#        15.0324, 20.3275, 37.0009, 15.2468, 19.3804, 29.9467, 17.9212,
#        29.8788, 26.671 , 23.627 , 15.1743, 16.6459, 30.0255, 14.3937,
#        33.9741, 20.8911, 44.8313, 32.9008, 15.2113, 14.981 , 26.7528,
#        17.9866, 17.0646, 30.8271, 14.1387, 17.0509, 20.1822, 36.0915,
#        15.1449, 29.4646, 20.1704, 16.7243, 26.402 , 26.0342, 15.1298,
#        15.1371, 40.2621, 14.7854, 14.1294, 29.8724, 15.0972, 31.3512,
#        36.6482, 37.4823, 17.9751, 14.585 , 17.7777, 26.328 , 15.8393,
#        13.8604, 15.173 , 21.2058, 34.0927, 15.6644, 13.6275, 17.6255,
#        28.9985, 16.8641, 33.9955, 29.5295, 13.8794, 29.9251, 31.9588])

# %%
z_pred.mean()
# Out:
# 23.534559740259738

# %%
mean_squared_error(b_test, z_pred)
# Out:
# 1.3058287990909077

# %%
np.sqrt(mean_squared_error(b_test, z_pred))
# Out:
# 1.1427286638090897

# %%
model_cold = lm.fit(A_train, b_train)
predictions_cold = lm.predict(A_test)

# %%
predictions_cold[0:5]
# Out:
# array([31.2476382 , 14.55715752, 16.55927941, 17.26778838, 40.12501688])

# %%
plt.scatter(b_test, predictions_cold)
plt.xlabel('True Values')
plt.ylabel('Predictions')
# Out:
# Text(0, 0.5, 'Predictions')

# %%
print ('Score:', model.score(A_test, b_test))
# Out:
# Score: 0.9608571209559367

# %%
y_pred = rf.predict(X_test)

# %%
y_pred
# Out:
# array([29.6514, 11.9945, 14.9391, 15.19  , 40.4543, 14.2292, 14.196 ,
#        14.5735, 32.671 , 11.6135, 24.3497, 19.4564, 14.4104,  6.7175,
#        29.4331, 10.3767, 14.768 , 13.1457, 32.9511, 12.9408, 14.5554,
#        24.4463, 16.6493, 12.2548, 14.5083, 33.9106, 24.0812, 29.4494,
#        25.534 , 12.9145, 10.3553, 22.1245, 42.6453, 28.3118, 15.0246,
#        42.3125, 24.454 , 16.0382, 36.571 , 35.5637,  8.271 ,  6.6099,
#        26.3178, 11.4719,  6.1323, 36.1062, 11.4649, 28.8682, 16.8639,
#        28.4051, 12.6527, 31.5248, 41.4062, 38.7698, 15.2535, 22.9456,
#        12.8716, 40.3793, 11.3318, 14.1546, 16.8233, 35.5731, 16.06  ,
#        23.6058, 11.5019, 25.3954, 16.9002, 15.2331, 10.1955, 29.6144,
#        28.5921, 34.3045, 26.584 , 12.2881, 36.6466, 16.4224, 11.5139,
#        26.7624, 35.7458, 14.466 , 38.6126, 14.4182, 26.6563, 15.0453,
#        32.6248, 15.8134, 16.5559, 14.4542, 11.1877, 23.5602,  6.6325,
#        12.458 , 16.8718, 36.5122, 12.2684, 15.323 , 27.8209, 15.181 ,
#        28.1483, 24.4099, 17.9291, 12.9537, 14.2687, 28.1012, 11.1546,
#        33.6139, 17.2791, 40.4711, 32.0953, 12.5807, 11.9291, 24.4699,
#        15.1274, 14.4565, 29.2273, 12.7627, 14.5158, 16.8011, 32.1971,
#        12.217 , 26.3426, 16.7867, 14.4014, 23.1384, 26.3244, 12.9939,
#        12.7261, 36.0008, 11.2655, 12.7524, 28.555 , 12.2516, 29.3758,
#        34.4351, 36.5627, 14.898 , 11.2962, 15.2138, 24.4121, 12.9382,
#        11.6119, 12.2119, 17.3702, 32.6763, 12.842 , 10.3984, 15.1608,
#        26.3775, 14.5785, 32.4389, 26.397 , 11.013 , 28.3023, 27.959 ])

# %%
y_pred.mean()
# Out:
# 20.951366883116886

# %%
mean_squared_error(y_test, y_pred)
# Out:
# 0.5450370152597416

# %%
heat = mean_squared_error(y_test, y_pred)

# %%
np.sqrt(mean_squared_error(y_test, y_pred))
# Out:
# 0.7382662224832865

# %%
from sklearn import datasets, linear_model

# %%
lm = linear_model.LinearRegression()
model = lm.fit(X_train, y_train)
predictions = lm.predict(X_test)

# %%
predictions[0:5]
# Out:
# array([31.31066492, 11.6613404 , 16.85390578, 16.86354413, 40.07324468])

# %%
print ('Score:', model.score(X_test, y_test))
# Out:
# Score: 0.9712526344250086

# %%
plt.scatter(y_test, predictions)
plt.axline((0,0), (3,3), color = 'red')
plt.xlabel('Actual Heating load')
plt.ylabel('Predicted Heating load')
plt.show()

# %%
plt.scatter(b_test, predictions_cold)
plt.axline((0,0), (3,3), color = 'red')
plt.xlabel('Actual Cooling load')
plt.ylabel('Predicted Coling load')
plt.show()
